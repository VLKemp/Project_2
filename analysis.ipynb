# %%
#Import Dependencies
import pandas as pd

# %%
#Create path to the reviews.csv file
reviews_file = "Resources/reviews.csv"

#Read the .csv file
reviews_df = pd.read_csv(reviews_file)

#View the .csv file
reviews_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
#Ascertain column headers
reviews_df.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
#Copy the dataframe with only the desired columns
reviews_df1 = reviews_df[['listing_id', 'id', 'date', 'reviewer_id', 'comments']].copy()
#View the dataframe
reviews_df1
# Out:
#        listing_id        id        date  reviewer_id  \
# 0         7202016  38917982  2015-07-19     28943674
# 1         7202016  39087409  2015-07-20     32440555
# 2         7202016  39820030  2015-07-26     37722850
# 3         7202016  40813543  2015-08-02     33671805
# 4         7202016  41986501  2015-08-10     34959538
# ...           ...       ...         ...          ...
# 84844     3624990  50436321  2015-10-12     37419458
# 84845     3624990  51024875  2015-10-17      6933252
# 84846     3624990  51511988  2015-10-20     19543701
# 84847     3624990  52814482  2015-11-02     24445024
# 84848     9727246  56429621  2015-12-13     30860360
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# 2      Very spacious apartment, and in a great neighb...
# 3      Close to Seattle Center and all it has to offe...
# ...

# %%
#Deleting rows with missing information
reviews_df1_miss = reviews_df1.dropna(how='any')
#View the dataframe
reviews_df1_miss
# Out:
#        listing_id        id        date  reviewer_id  \
# 0         7202016  38917982  2015-07-19     28943674
# 1         7202016  39087409  2015-07-20     32440555
# 2         7202016  39820030  2015-07-26     37722850
# 3         7202016  40813543  2015-08-02     33671805
# 4         7202016  41986501  2015-08-10     34959538
# ...           ...       ...         ...          ...
# 84844     3624990  50436321  2015-10-12     37419458
# 84845     3624990  51024875  2015-10-17      6933252
# 84846     3624990  51511988  2015-10-20     19543701
# 84847     3624990  52814482  2015-11-02     24445024
# 84848     9727246  56429621  2015-12-13     30860360
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# 2      Very spacious apartment, and in a great neighb...
# 3      Close to Seattle Center and all it has to offe...
# ...

# %%
#Deleting any duplicates 
reviews_df1_miss.drop_duplicates(inplace=True)

#View the dataframe
reviews_df1_miss
# Out:
#        listing_id        id        date  reviewer_id  \
# 0         7202016  38917982  2015-07-19     28943674
# 1         7202016  39087409  2015-07-20     32440555
# 2         7202016  39820030  2015-07-26     37722850
# 3         7202016  40813543  2015-08-02     33671805
# 4         7202016  41986501  2015-08-10     34959538
# ...           ...       ...         ...          ...
# 84844     3624990  50436321  2015-10-12     37419458
# 84845     3624990  51024875  2015-10-17      6933252
# 84846     3624990  51511988  2015-10-20     19543701
# 84847     3624990  52814482  2015-11-02     24445024
# 84848     9727246  56429621  2015-12-13     30860360
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# 2      Very spacious apartment, and in a great neighb...
# 3      Close to Seattle Center and all it has to offe...
# ...

# %%
#Ascertaining the column data types
reviews_df1_miss.dtypes
# Out:
# listing_id      int64
# id              int64
# date           object
# reviewer_id     int64
# comments       object
# dtype: object

# %%
#Converting date column to datetime format and to check it has worked
pd.to_datetime(reviews_df1_miss['date'], format='%Y-%m-%d', errors='coerce').notnull().all()
# Out:
# True

# %%
#Convert the comments column from object to string type
reviews_df1_drop["comments"] = reviews_df1_drop["comments"].astype("|S")
#View the dataframe
reviews_df1_drop
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# UnicodeEncodeError: 'ascii' codec can't encode character '\xe1' in position 219: ordinal not in range(128)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <class 'UnicodeEncodeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <class 'UnicodeEncodeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <class 'UnicodeEncodeError'> returned a result with an error set
#
# ...
